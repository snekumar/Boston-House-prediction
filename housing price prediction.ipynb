# %% [markdown]
# # 1.Importing the modules

# %%
#importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.datasets
sns.set_style('whitegrid')
# %matplotlib inline

# %%
# Importing the Boston Housing dataset
from sklearn.datasets import load_boston
boston = load_boston()

# %%
#reading the dataset
data = pd.read_csv('boston.csv')
print("Boston housing dataset has {} data points with {} variables each.".format(*data.shape)) #no of dataset
# Out:
# Boston housing dataset has 506 data points with 16 variables each.

# %%
data.info() #to get the summary of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   TOWN     506 non-null    object
#  1   TRACT    506 non-null    int64
#  2   LON      506 non-null    float64
#  3   LAT      506 non-null    float64
#  4   MEDV     506 non-null    float64
#  5   CRIM     506 non-null    float64
#  6   ZN       506 non-null    float64
#  7   INDUS    506 non-null    float64
#  8   CHAS     506 non-null    int64
#  9   NOX      506 non-null    float64
#  10  RM       506 non-null    float64
#  11  AGE      506 non-null    float64
#  12  DIS      506 non-null    float64
#  13  RAD      506 non-null    int64
#  14  TAX      506 non-null    int64
#  15  PTRATIO  506 non-null    float64
# dtypes: float64(11), int64(4), object(1)
# memory usage: 63.4+ KB

# %%
data.head() # See head of the dataset
# Out:
#          TOWN  TRACT     LON      LAT  MEDV     CRIM    ZN  INDUS  CHAS  \
# 0      Nahant   2011 -70.955  42.2550  24.0  0.00632  18.0   2.31     0
# 1  Swampscott   2021 -70.950  42.2875  21.6  0.02731   0.0   7.07     0
# 2  Swampscott   2022 -70.936  42.2830  34.7  0.02729   0.0   7.07     0
# 3  Marblehead   2031 -70.928  42.2930  33.4  0.03237   0.0   2.18     0
# 4  Marblehead   2032 -70.922  42.2980  36.2  0.06905   0.0   2.18     0
#
#      NOX     RM   AGE     DIS  RAD  TAX  PTRATIO
# 0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.458  7.147  54.2  6.0622    3  222     18.7

# %%
#Adding the feature names to the dataframe
data.columns = boston.feature_names
data.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-d2fef1de1780> in <module>
#       1 #Adding the feature names to the dataframe
# ----> 2 data.columns = boston.feature_names
#       3 data.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5150         try:
#    5151             object.__getattribute__(self, name)
# -> 5152             return object.__setattr__(self, name, value)
#    5153         except AttributeError:
#    5154             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     562     def _set_axis(self, axis: int, labels: Index) -> None:
#     563         labels = ensure_index(labels)
# --> 564         self._mgr.set_axis(axis, labels)
# ...

# %% [markdown]
# # 2. Adding target variable to dataframe

# %%
#Adding target variable to dataframe
data['boston'] = data.target 
# Median value of owner-occupied homes in $1000s
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-b108cadeb039> in <module>
#       1 #Adding target variable to dataframe
# ----> 2 data['boston'] = data.target
#       3 # Median value of owner-occupied homes in $1000s
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'target'

# %%
data.columns #the columns title
# Out:
# Index(['TOWN', 'TRACT', 'LON', 'LAT', 'MEDV', 'CRIM', 'ZN', 'INDUS', 'CHAS',
#        'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO'],
#       dtype='object')

# %%
# Identifying the unique number of values in the dataset
data.nunique()
# Out:
# TOWN        92
# TRACT      506
# LON        375
# LAT        376
# MEDV       228
# CRIM       504
# ZN          26
# INDUS       76
# CHAS         2
# NOX         81
# RM         446
# AGE        356
# DIS        412
# RAD          9
# TAX         66
# PTRATIO     46
# dtype: int64

# %%
sns.set_palette("GnBu_d")
sns.set_style('whitegrid')
sns.pairplot(data,size = 2,vars = ['CRIM','NOX','RAD','DIS','MEDV'])
# Out:
# C:\Users\hi\anaconda3\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
data.corr()
# Out:
#             TRACT       LON       LAT      MEDV      CRIM        ZN     INDUS  \
# TRACT    1.000000 -0.220890 -0.225543  0.428252 -0.547165  0.367292 -0.575705
# LON     -0.220890  1.000000  0.143054 -0.322947  0.065101 -0.218081  0.062702
# LAT     -0.225543  0.143054  1.000000  0.006826 -0.084293 -0.129667 -0.041093
# MEDV     0.428252 -0.322947  0.006826  1.000000 -0.389582  0.360386 -0.484754
# CRIM    -0.547165  0.065101 -0.084293 -0.389582  1.000000 -0.200469  0.406583
# ZN       0.367292 -0.218081 -0.129667  0.360386 -0.200469  1.000000 -0.533828
# INDUS   -0.575705  0.062702 -0.041093 -0.484754  0.406583 -0.533828  1.000000
# CHAS     0.041356 -0.175619 -0.044726  0.175663 -0.055892 -0.042697  0.062938
# NOX     -0.569807  0.160871 -0.068600 -0.429300  0.420972 -0.516604  0.763651
# RM       0.305207 -0.257110 -0.069317  0.696304 -0.219247  0.311991 -0.391676
# AGE     -0.487465  0.204739  0.079035 -0.377999  0.352734 -0.569537  0.644779
# ...

# %%
# Import library for Linear Regression
from sklearn.linear_model import LinearRegression

# Create a Linear regressor
lm = LinearRegression()

# Train the model using the training sets 
lm.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-62b41583ad2f> in <module>
#       6
#       7 # Train the model using the training sets
# ----> 8 lm.fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined

# %%
print(lm.intercept_)
# Out:
# 28.547769778627952

# %%
coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#          Coefficient
# CRIM       -0.170335
# ZN          0.039893
# INDUS      -0.095109
# CHAS        2.431655
# NOX       -22.498404
# RM          5.762281
# AGE        -0.042962
# DIS        -1.577240
# RAD         0.028790
# PTRATIO    -1.092756

# %%
Predictions = lm.predict(X_test)
# Let's check through a scatter plot how they are aligned
plt.scatter(y_test,Predictions)

# %%
#residual Histogram
sns.distplot((y_test-Predictions),bins=50)
# Out:
# C:\Users\hi\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MEDV', ylabel='Density'>

# %%
# Model prediction on train data
y_pred = lm.predict(X_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-08378fab4e44> in <module>
#       1 # Model prediction on train data
# ----> 2 y_pred = lm.predict(X_train)
#
# NameError: name 'lm' is not defined

# %%
#Regression Evaluation Metrics
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, Predictions))
print('MSE:', metrics.mean_squared_error(y_test, Predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, Predictions)))
# Out:
# MAE: 3.926130637590449
# MSE: 36.80775786272037
# RMSE: 6.066939744444507

# %%
# Visualizing the differences between actual prices and predicted values
plt.scatter(y_train, y_pred)
plt.xlabel("Prices")
plt.ylabel("Predicted prices")
plt.title("Prices vs Predicted prices")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-74632fa847b5> in <module>
#       1 # Visualizing the differences between actual prices and predicted values
# ----> 2 plt.scatter(y_train, y_pred)
#       3 plt.xlabel("Prices")
#       4 plt.ylabel("Predicted prices")
#       5 plt.title("Prices vs Predicted prices")
#
# NameError: name 'y_train' is not defined
